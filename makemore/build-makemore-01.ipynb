# %%
import sys, os
print(os.getcwd())
print(sys.executable)
print(sys.path[0])
# Out:
# c:\Users\trakw\_workspace\micrograd-from-scratch
# c:\Users\trakw\_workspace\micrograd-from-scratch\.venv\Scripts\python.exe
# C:\Users\trakw\miniforge3\python313.zip

# %%
# โหลด name.txt
words = open("makemore/names.txt", 'r').read().splitlines()

# %%
len(words)
# Out:
# 32033

# %%
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
min(len(w) for w in words)
# Out:
# 2

# %%
max(len(w) for w in words)
# Out:
# 15

# %%
list(filter(lambda w: len(w)==2, words))

# %%
word_set = sorted(set(''.join(words)))
stoi = {s:i for s, i in zip(word_set, range(1, 27))}
stoi['.'] = 0
itos = {i:s for s, i in stoi.items()}

# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = torch.zeros(27, 27).int()

# %%
for w in words:
    w = "." + w + "."
    for ch1, ch2 in zip(w, w[1:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        N[ix1, ix2] += 1

# %%
N[0, 0].item()
# Out:
# 0

# %%
plt.figure(figsize=(16, 16))
plt.imshow(N, cmap="Blues")
for i in range(27):
    for j in range(27):
        plt.text(j, i, itos[i] + itos[j], va = "bottom", ha = "center")
        plt.text(j, i, N[i, j].item(), va = "top", ha = "center")

# %%
# Out:
# tensor([1026])

# %%
P = N / N.sum(dim = 1, keepdim=True)

# %%
P.sum(dim = 1, keepdim=True)
# Out:
# tensor([[1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000],
#         [1.0000]])

# %%
X = [[0, 1, 2], [2, 1, 0]]
plt.imshow(X, cmap="Blues")
plt.text(1, 0, "a")
# Out:
# Text(1, 0, 'a')

# %%
print(X[1][0])
# Out:
# 2
